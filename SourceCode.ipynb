# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_test=pd.read_csv("C:/Users/91965/Downloads/Project_1/Project 1/test.csv")

# %%
df_train=train = pd.read_csv("C:/Users/91965/Downloads/Project_1/Project 1/train.csv")

# %%
df_train
# Out:
#           UID  BLOCKID  SUMLEVEL  COUNTYID  STATEID         state state_ab  \
# 0      267822      NaN       140        53       36      New York       NY
# 1      246444      NaN       140       141       18       Indiana       IN
# 2      245683      NaN       140        63       18       Indiana       IN
# 3      279653      NaN       140       127       72   Puerto Rico       PR
# 4      247218      NaN       140       161       20        Kansas       KS
# ...       ...      ...       ...       ...      ...           ...      ...
# 27316  279212      NaN       140        43       72   Puerto Rico       PR
# 27317  277856      NaN       140        91       42  Pennsylvania       PA
# 27318  233000      NaN       140        87        8      Colorado       CO
# 27319  287425      NaN       140       439       48         Texas       TX
# 27320  265371      NaN       140         3       32        Nevada       NV
#
# ...

# %%
df_test
# Out:
#           UID  BLOCKID  SUMLEVEL  COUNTYID  STATEID          state state_ab  \
# 0      255504      NaN       140       163       26       Michigan       MI
# 1      252676      NaN       140         1       23          Maine       ME
# 2      276314      NaN       140        15       42   Pennsylvania       PA
# 3      248614      NaN       140       231       21       Kentucky       KY
# 4      286865      NaN       140       355       48          Texas       TX
# ...       ...      ...       ...       ...      ...            ...      ...
# 11704  238088      NaN       140       105       12        Florida       FL
# 11705  242811      NaN       140        31       17       Illinois       IL
# 11706  250127      NaN       140         9       25  Massachusetts       MA
# 11707  241096      NaN       140        27       19           Iowa       IA
# 11708  287763      NaN       140       453       48          Texas       TX
#
# ...

# %% [markdown]
# ## 2. Figure out the primary key and look for the requirement of indexing.

# %%
df_train.nunique()
# Out:
# UID            27161
# BLOCKID            0
# SUMLEVEL           1
# COUNTYID         296
# STATEID           52
#                ...
# pct_own        22302
# married        20282
# married_snp    10350
# separated       6190
# divorced       13688
# Length: 80, dtype: int64

# %%
df_test.nunique()
# Out:
# UID            11677
# BLOCKID            0
# SUMLEVEL           1
# COUNTYID         246
# STATEID           52
#                ...
# pct_own        10578
# married        10215
# married_snp     6829
# separated       4512
# divorced        8273
# Length: 80, dtype: int64

# %%
df_train.sort_values(by= 'UID', ascending= True, inplace = True)
df_train.reset_index(drop = True, inplace = True)
df_train
# Out:
#           UID  BLOCKID  SUMLEVEL  COUNTYID  STATEID    state state_ab  \
# 0      220342      NaN       140        20        2   Alaska       AK
# 1      220345      NaN       140        20        2   Alaska       AK
# 2      220347      NaN       140        20        2   Alaska       AK
# 3      220348      NaN       140        20        2   Alaska       AK
# 4      220349      NaN       140        20        2   Alaska       AK
# ...       ...      ...       ...       ...      ...      ...      ...
# 27316  294321      NaN       140        37       56  Wyoming       WY
# 27317  294326      NaN       140        39       56  Wyoming       WY
# 27318  294327      NaN       140        41       56  Wyoming       WY
# 27319  294331      NaN       140        43       56  Wyoming       WY
# 27320  294334      NaN       140        45       56  Wyoming       WY
#
#                 city              place  type  ... female_age_mean  \
# ...

# %%
df_test.sort_values(by = 'UID',ascending = True, inplace = True)
df_test.reset_index(drop = True, inplace = True)
df_test
# Out:
#           UID  BLOCKID  SUMLEVEL  COUNTYID  STATEID    state state_ab  \
# 0      220336      NaN       140        16        2   Alaska       AK
# 1      220343      NaN       140        20        2   Alaska       AK
# 2      220352      NaN       140        20        2   Alaska       AK
# 3      220355      NaN       140        20        2   Alaska       AK
# 4      220364      NaN       140        20        2   Alaska       AK
# ...       ...      ...       ...       ...      ...      ...      ...
# 11704  294285      NaN       140        25       56  Wyoming       WY
# 11705  294296      NaN       140        29       56  Wyoming       WY
# 11706  294308      NaN       140        33       56  Wyoming       WY
# 11707  294313      NaN       140        37       56  Wyoming       WY
# 11708  294333      NaN       140        45       56  Wyoming       WY
#
#               city             place  type  ... female_age_mean  \
# ...

# %% [markdown]
# ## Gauge the fill rate of the variables and devise plans for missing value treatment.
# ## Please explain explicitly the reason for the treatment chosen for each variable.

# %%
df_test.isna().sum()[df_test.isna().sum()!=0.]/11709*100
# Out:
# BLOCKID                        100.000000
# rent_mean                        1.263985
# rent_median                      1.263985
# rent_stdev                       1.263985
# rent_sample_weight               1.263985
# rent_samples                     1.263985
# rent_gt_10                       1.272525
# rent_gt_15                       1.272525
# rent_gt_20                       1.272525
# rent_gt_25                       1.272525
# rent_gt_30                       1.272525
# rent_gt_35                       1.272525
# rent_gt_40                       1.272525
# rent_gt_50                       1.272525
# hi_mean                          1.041934
# hi_median                        1.041934
# hi_stdev                         1.041934
# hi_sample_weight                 1.041934
# hi_samples                       1.041934
# family_mean                      1.161500
# family_median                    1.161500
# family_stdev                     1.161500
# ...

# %%
df_test.isna().sum()[df_test.isna().sum()>0].shape
# Out:
# (59,)

# %%
df_test.drop(["BLOCKID"], axis=1, inplace = True)

# %% [markdown]
# ### We have dropped BLOCKID as 100 percent of the column values are missing

# %%
df_test.rent_mean.fillna(df_test.rent_mean.mean(),inplace = True)
df_test.rent_median.fillna(df_test.rent_median.mean(),inplace = True)
df_test.rent_stdev.fillna(df_test.rent_stdev.mean(),inplace = True)
df_test.rent_sample_weight.fillna(df_test.rent_sample_weight.mean(),inplace = True)

# %%
from sklearn.impute import SimpleImputer

imp_mean = SimpleImputer(strategy ="mean")
imp_median = SimpleImputer(strategy = "median")
imp_mode = SimpleImputer(strategy = "mode")

# %%
df_test['rent_samples']            =    imp_mean.fit_transform(df_test[['rent_samples']])
df_test['rent_gt_10']              =    imp_mean.fit_transform(df_test[['rent_gt_10']])
df_test['rent_gt_15']              =    imp_mean.fit_transform(df_test[['rent_gt_15']])
df_test['rent_gt_20']              =    imp_mean.fit_transform(df_test[['rent_gt_20']])
df_test['rent_gt_25']              =    imp_mean.fit_transform(df_test[['rent_gt_25']])
df_test['rent_gt_30']              =    imp_mean.fit_transform(df_test[['rent_gt_30']])
df_test['rent_gt_35']              =    imp_mean.fit_transform(df_test[['rent_gt_35']])
df_test['rent_gt_40']              =    imp_mean.fit_transform(df_test[['rent_gt_40']])
df_test['rent_gt_50']              =    imp_mean.fit_transform(df_test[['rent_gt_50']])
df_test['hi_mean']                 =    imp_mean.fit_transform(df_test[['hi_mean']])
df_test['hi_median']               =    imp_mean.fit_transform(df_test[['hi_median']])
df_test['hi_stdev']                =    imp_mean.fit_transform(df_test[['hi_stdev']])
df_test['hi_sample_weight']        =    imp_mean.fit_transform(df_test[['hi_sample_weight']])
df_test['hi_samples']              =    imp_mean.fit_transform(df_test[['hi_samples']])
df_test['family_mean']             =    imp_mean.fit_transform(df_test[['family_mean']])
df_test['family_median']           =    imp_mean.fit_transform(df_test[['family_median']])
df_test['family_stdev']            =    imp_mean.fit_transform(df_test[['family_stdev']])
df_test['family_sample_weight']    =    imp_mean.fit_transform(df_test[['family_sample_weight']])
df_test['family_samples']          =    imp_mean.fit_transform(df_test[['family_samples']])
df_test['hc_mortgage_mean']        =    imp_mean.fit_transform(df_test[['hc_mortgage_mean']])
df_test['hc_mortgage_median']      =    imp_mean.fit_transform(df_test[['hc_mortgage_median']])
df_test['hc_mortgage_stdev']       =    imp_mean.fit_transform(df_test[['hc_mortgage_stdev']])
df_test['hc_mortgage_sample_weight']  = imp_mean.fit_transform(df_test[['hc_mortgage_sample_weight']])
df_test['hc_mortgage_samples']     =    imp_mean.fit_transform(df_test[['hc_mortgage_samples']])
df_test['hc_mean']                 =    imp_mean.fit_transform(df_test[['hc_mean']])
df_test['hc_median']               =    imp_mean.fit_transform(df_test[['hc_median']])
df_test['hc_stdev']                =    imp_mean.fit_transform(df_test[['hc_stdev']])
df_test['hc_sample_weight']        =    imp_mean.fit_transform(df_test[['hc_sample_weight']])
df_test['hc_samples']              =    imp_mean.fit_transform(df_test[['hc_samples']]) 
df_test['home_equity_second_mortgage']= imp_mean.fit_transform(df_test[['home_equity_second_mortgage']])
df_test['second_mortgage']         =    imp_mean.fit_transform(df_test[['second_mortgage']]) 
df_test['home_equity_cdf']         =    imp_mean.fit_transform(df_test[['home_equity_cdf']])
df_test['debt_cdf']                =    imp_mean.fit_transform(df_test[['debt_cdf']])
df_test['hs_degree']               =    imp_mean.fit_transform(df_test[['hs_degree']])
df_test['hs_degree_male']          =    imp_mean.fit_transform(df_test[['hs_degree_male']])
df_test['hs_degree_female']        =    imp_mean.fit_transform(df_test[['hs_degree_female']])
df_test['male_age_mean']           =    imp_mean.fit_transform(df_test[['male_age_mean']])
df_test['male_age_median']         =    imp_mean.fit_transform(df_test[['male_age_median']])
df_test['male_age_stdev']          =    imp_mean.fit_transform(df_test[['male_age_stdev']])
df_test['male_age_sample_weight']  =    imp_mean.fit_transform(df_test[['male_age_sample_weight']])
df_test['male_age_samples']        =    imp_mean.fit_transform(df_test[['male_age_samples']])
df_test['female_age_mean']         =    imp_mean.fit_transform(df_test[['female_age_mean']])
df_test['female_age_median']       =    imp_mean.fit_transform(df_test[['female_age_median']])
df_test['female_age_stdev']        =    imp_mean.fit_transform(df_test[['female_age_stdev']])
df_test['female_age_sample_weight']  =  imp_mean.fit_transform(df_test[['female_age_sample_weight']])
df_test['female_age_samples']      =    imp_mean.fit_transform(df_test[['female_age_samples']]) 
df_test['pct_own']                 =    imp_mean.fit_transform(df_test[['pct_own']])
df_test['married']                 =    imp_mean.fit_transform(df_test[['married']])
df_test['married_snp']             =    imp_mean.fit_transform(df_test[['married_snp']])
df_test['separated']               =    imp_mean.fit_transform(df_test[['separated']])
df_test['divorced']                =    imp_mean.fit_transform(df_test[['divorced']])
df_test["home_equity"]             =    imp_mean.fit_transform(df_test[['home_equity']])
df_test["debt"]                    =    imp_mean.fit_transform(df_test[['debt']])
df_test["second_mortgage_cdf"]     =    imp_mean.fit_transform(df_test[["second_mortgage_cdf"]])

# %%
df_test.isna().sum()[df_test.isna().sum()>0]
# Out:
# Series([], dtype: int64)

# %%
df_train.isna().sum()[df_train.isna().sum()>0]/27321*100
# Out:
# BLOCKID                        100.000000
# rent_mean                        1.149299
# rent_median                      1.149299
# rent_stdev                       1.149299
# rent_sample_weight               1.149299
# rent_samples                     1.149299
# rent_gt_10                       1.149299
# rent_gt_15                       1.149299
# rent_gt_20                       1.149299
# rent_gt_25                       1.149299
# rent_gt_30                       1.149299
# rent_gt_35                       1.149299
# rent_gt_40                       1.149299
# rent_gt_50                       1.149299
# hi_mean                          0.980930
# hi_median                        0.980930
# hi_stdev                         0.980930
# hi_sample_weight                 0.980930
# hi_samples                       0.980930
# family_mean                      1.090736
# family_median                    1.090736
# family_stdev                     1.090736
# ...

# %%
### We are dropping BLOCKID as 100 percent of the column values are missing

# %%
df_train.drop(['BLOCKID'], axis=1, inplace = True)

# %%
df_train['rent_mean']               =    imp_mean.fit_transform(df_train[['rent_mean']])
df_train['rent_median']             =    imp_mean.fit_transform(df_train[['rent_median']])
df_train['rent_stdev']              =    imp_mean.fit_transform(df_train[['rent_stdev']])
df_train['rent_sample_weight']      =    imp_mean.fit_transform(df_train[['rent_sample_weight']])
df_train['rent_samples']            =    imp_mean.fit_transform(df_train[['rent_samples']])
df_train['rent_gt_10']              =    imp_mean.fit_transform(df_train[['rent_gt_10']])
df_train['rent_gt_15']              =    imp_mean.fit_transform(df_train[['rent_gt_15']])
df_train['rent_gt_20']              =    imp_mean.fit_transform(df_train[['rent_gt_20']])
df_train['rent_gt_25']              =    imp_mean.fit_transform(df_train[['rent_gt_25']])
df_train['rent_gt_30']              =    imp_mean.fit_transform(df_train[['rent_gt_30']])
df_train['rent_gt_35']              =    imp_mean.fit_transform(df_train[['rent_gt_35']])
df_train['rent_gt_40']              =    imp_mean.fit_transform(df_train[['rent_gt_40']])
df_train['rent_gt_50']              =    imp_mean.fit_transform(df_train[['rent_gt_50']])
df_train['hi_mean']                 =    imp_mean.fit_transform(df_train[['hi_mean']])
df_train['hi_median']               =    imp_mean.fit_transform(df_train[['hi_median']])
df_train['hi_stdev']                =    imp_mean.fit_transform(df_train[['hi_stdev']])
df_train['hi_sample_weight']        =    imp_mean.fit_transform(df_train[['hi_sample_weight']])
df_train['hi_samples']              =    imp_mean.fit_transform(df_train[['hi_samples']])
df_train['family_mean']             =    imp_mean.fit_transform(df_train[['family_mean']])
df_train['family_median']           =    imp_mean.fit_transform(df_train[['family_median']])
df_train['family_stdev']            =    imp_mean.fit_transform(df_train[['family_stdev']])
df_train['family_sample_weight']    =    imp_mean.fit_transform(df_train[['family_sample_weight']])
df_train['family_samples']          =    imp_mean.fit_transform(df_train[['family_samples']])
df_train['hc_mortgage_mean']        =    imp_mean.fit_transform(df_train[['hc_mortgage_mean']])
df_train['hc_mortgage_median']      =    imp_mean.fit_transform(df_train[['hc_mortgage_median']])
df_train['hc_mortgage_stdev']       =    imp_mean.fit_transform(df_train[['hc_mortgage_stdev']])
df_train['hc_mortgage_sample_weight']  = imp_mean.fit_transform(df_train[['hc_mortgage_sample_weight']])
df_train['hc_mortgage_samples']     =    imp_mean.fit_transform(df_train[['hc_mortgage_samples']])
df_train['hc_mean']                 =    imp_mean.fit_transform(df_train[['hc_mean']])
df_train['hc_median']               =    imp_mean.fit_transform(df_train[['hc_median']])
df_train['hc_stdev']                =    imp_mean.fit_transform(df_train[['hc_stdev']])
df_train['hc_sample_weight']        =    imp_mean.fit_transform(df_train[['hc_sample_weight']])
df_train['hc_samples']              =    imp_mean.fit_transform(df_train[['hc_samples']]) 
df_train['home_equity_second_mortgage']= imp_mean.fit_transform(df_train[['home_equity_second_mortgage']])
df_train['second_mortgage']         =    imp_mean.fit_transform(df_train[['second_mortgage']]) 
df_train['home_equity_cdf']         =    imp_mean.fit_transform(df_train[['home_equity_cdf']])
df_train['debt_cdf']                =    imp_mean.fit_transform(df_train[['debt_cdf']])
df_train['hs_degree']               =    imp_mean.fit_transform(df_train[['hs_degree']])
df_train['hs_degree_male']          =    imp_mean.fit_transform(df_train[['hs_degree_male']])
df_train['hs_degree_female']        =    imp_mean.fit_transform(df_train[['hs_degree_female']])
df_train['male_age_mean']           =    imp_mean.fit_transform(df_train[['male_age_mean']])
df_train['male_age_median']         =    imp_mean.fit_transform(df_train[['male_age_median']])
df_train['male_age_stdev']          =    imp_mean.fit_transform(df_train[['male_age_stdev']])
df_train['male_age_sample_weight']  =    imp_mean.fit_transform(df_train[['male_age_sample_weight']])
df_train['male_age_samples']        =    imp_mean.fit_transform(df_train[['male_age_samples']])
df_train['female_age_mean']         =    imp_mean.fit_transform(df_train[['female_age_mean']])
df_train['female_age_median']       =    imp_mean.fit_transform(df_train[['female_age_median']])
df_train['female_age_stdev']        =    imp_mean.fit_transform(df_train[['female_age_stdev']])
df_train['female_age_sample_weight']  =  imp_mean.fit_transform(df_train[['female_age_sample_weight']])
df_train['female_age_samples']      =    imp_mean.fit_transform(df_train[['female_age_samples']]) 
df_train['pct_own']                 =    imp_mean.fit_transform(df_train[['pct_own']])
df_train['married']                 =    imp_mean.fit_transform(df_train[['married']])
df_train['married_snp']             =    imp_mean.fit_transform(df_train[['married_snp']])
df_train['separated']               =    imp_mean.fit_transform(df_train[['separated']])
df_train['divorced']                =    imp_mean.fit_transform(df_train[['divorced']])
df_train["home_equity"]             =    imp_mean.fit_transform(df_train[['home_equity']])
df_train["debt"]                    =    imp_mean.fit_transform(df_train[['debt']])
df_train["second_mortgage_cdf"]     =    imp_mean.fit_transform(df_train[["second_mortgage_cdf"]])

# %%
df_train.isna().sum()[df_train.isna().sum()>0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ## We have majorly all the missing variables with the mean of their respective columns.

# %% [markdown]
# ##
# ___________________________________________________________________________

# %% [markdown]
# ## 4.Perform debt analysis. You may take the following steps:
#
# a) Explore the top 2,500 locations where the percentage of households with a second mortgage is the highest and percent ownership is above 10 percent. Visualize using geo-map. You may keep the upper limit for the percent of households with a second mortgage to 50 percent

# %%
df_train_2500 = df_train.nlargest(2500,["second_mortgage"])
df_train_2500
# Out:
#           UID  SUMLEVEL  COUNTYID  STATEID          state state_ab  \
# 10201  247937       140        93       21       Kentucky       KY
# 10202  247937       140        93       21       Kentucky       KY
# 10370  248394       140       163       21       Kentucky       KY
# 10874  249744       140       115       22      Louisiana       LA
# 25716  290029       140       510       51       Virginia       VA
# ...       ...       ...       ...      ...            ...      ...
# 5303   234809       140        11       12        Florida       FL
# 5526   235379       140        31       12        Florida       FL
# 11352  251046       140        25       25  Massachusetts       MA
# 5894   236385       140        83       12        Florida       FL
# 16309  264444       140        31       34     New Jersey       NJ
#
#                    city                  place  type primary  ...  \
# 10201         Fort Knox              Fort Knox  City   tract  ...
# ...

# %%
threshold = df_train_2500['pct_own'].quantile(0.1)
threshold
# Out:
# 0.221558

# %%
above_threshold = df_train_2500[df_train_2500['pct_own']> threshold]
above_threshold
# Out:
#           UID  SUMLEVEL  COUNTYID  STATEID          state state_ab  \
# 25593  289712       140       147       51       Virginia       VA
# 11461  251324       140         3       24       Maryland       MD
# 8228   242546       140        31       17       Illinois       IL
# 12322  253669       140        65       26       Michigan       MI
# 26816  292972       140        79       55      Wisconsin       WI
# ...       ...       ...       ...      ...            ...      ...
# 27098  293726       140         3       54  West Virginia       WV
# 5303   234809       140        11       12        Florida       FL
# 5526   235379       140        31       12        Florida       FL
# 11352  251046       140        25       25  Massachusetts       MA
# 5894   236385       140        83       12        Florida       FL
#
#                    city                  place     type primary  ...  \
# 25593         Farmville              Farmville     Town   tract  ...
# ...

# %%
above_threshold.sort_values(by = "UID", ascending = True, inplace = True)
above_threshold.reset_index(drop= True, inplace = True)
above_threshold
# Out:
# C:\Users\91965\AppData\Local\Temp\ipykernel_12004\1457807460.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   above_threshold.sort_values(by = "UID", ascending = True, inplace = True)
#          UID  SUMLEVEL  COUNTYID  STATEID    state state_ab          city  \
# 0     220366       140        20        2   Alaska       AK     Anchorage
# 1     220403       140        90        2   Alaska       AK     Fairbanks
# 2     220505       140         1        1  Alabama       AL    Prattville
# 3     220719       140        43        1  Alabama       AL       Cullman
# 4     220899       140        73        1  Alabama       AL    Birmingham
# ...      ...       ...       ...      ...      ...      ...           ...
# 2245  294253       140        21       56  Wyoming       WY      Cheyenne
# ...

# %%
above_threshold.to_excel("above_threshold.xlsx")

# %%
df_train_2500["bad_debt"] =  df_train_2500['second_mortgage'] + df_train_2500 ['home_equity'] - df_train_2500['home_equity_second_mortgage']
df_train_2500.bad_debt
# Out:
# 10201    1.00000
# 10202    1.00000
# 10370    1.00000
# 10874    1.00000
# 25716    1.00000
#           ...
# 5303     0.08577
# 5526     0.12134
# 11352    0.11044
# 5894     0.08506
# 16309    0.06897
# Name: bad_debt, Length: 2500, dtype: float64

# %%
df_train_2500.bad_debt.sum()
# Out:
# 458.15097000000003

# %%
df_train_2500.debt.sum()
# Out:
# 1842.26915

# %%
debts = pd.DataFrame({"types":['debt',"bad_debt"], "Values":[1842.26915,458.15097000000003]})

# %% [markdown]
# ### c) Create pie charts to show overall debt and bad debt

# %%
plt.pie(debts['Values'], labels = debts["types"], colors =['skyblue','red'],autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ## d) Create Box and whisker plot and analyze the distribution for 2nd mortgage, home equity, good debt, and bad debt for different cities

# %%
df_train_2500.city.value_counts()
# Out:
# Chicago            50
# Los Angeles        41
# Washington         26
# Brooklyn           24
# Milwaukee          20
#                    ..
# River Falls         1
# East Rutherford     1
# Elmhurst            1
# Woodlake            1
# Ocala               1
# Name: city, Length: 1150, dtype: int64

# %%
df_train_2500['good_debt'] = df_train_2500['debt'] - df_train_2500['bad_debt']

# %%
df_box_chicago=df_train_2500.loc[df_train_2500['city'] == 'Chicago']
df_box_LA=df_train_2500.loc[df_train_2500['city'] == "Los Angeles"]
df_box_city=pd.concat([df_box_chicago,df_box_LA])
df_box_city.head()
# Out:
#          UID  SUMLEVEL  COUNTYID  STATEID     state state_ab     city  \
# 8287  242690       140        31       17  Illinois       IL  Chicago
# 8136  242304       140        31       17  Illinois       IL  Chicago
# 8228  242546       140        31       17  Illinois       IL  Chicago
# 8289  242693       140        31       17  Illinois       IL  Chicago
# 8288  242691       140        31       17  Illinois       IL  Chicago
#
#              place     type primary  ...  female_age_stdev  \
# 8287  Chicago City  Village   tract  ...          23.19396
# 8136   Lincolnwood  Village   tract  ...          21.71686
# 8228  Chicago City  Village   tract  ...          17.18452
# 8289  Chicago City  Village   tract  ...          21.29440
# 8288  Chicago City  Village   tract  ...          19.20161
#
#       female_age_sample_weight  female_age_samples  pct_own  married  \
# 8287                 199.89534               880.0  0.05267  0.43648
# ...

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df_box_city,x='second_mortgage', y='city',width=0.5,palette="Set3")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df_box_city,x='home_equity', y='city',width=0.5,palette="Set3")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df_box_city,x='good_debt', y='city',width=0.5,palette="Set3")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df_box_city,x='bad_debt', y='city',width=0.5,palette="Set3")
plt.show()

# %% [markdown]
# ## e) Create a collated income distribution chart for family income, house hold income, and remaining income

# %%
df_train_2500.columns
# Out:
# Index(['UID', 'SUMLEVEL', 'COUNTYID', 'STATEID', 'state', 'state_ab', 'city',
#        'place', 'type', 'primary', 'zip_code', 'area_code', 'lat', 'lng',
#        'ALand', 'AWater', 'pop', 'male_pop', 'female_pop', 'rent_mean',
#        'rent_median', 'rent_stdev', 'rent_sample_weight', 'rent_samples',
#        'rent_gt_10', 'rent_gt_15', 'rent_gt_20', 'rent_gt_25', 'rent_gt_30',
#        'rent_gt_35', 'rent_gt_40', 'rent_gt_50', 'universe_samples',
#        'used_samples', 'hi_mean', 'hi_median', 'hi_stdev', 'hi_sample_weight',
#        'hi_samples', 'family_mean', 'family_median', 'family_stdev',
#        'family_sample_weight', 'family_samples', 'hc_mortgage_mean',
#        'hc_mortgage_median', 'hc_mortgage_stdev', 'hc_mortgage_sample_weight',
#        'hc_mortgage_samples', 'hc_mean', 'hc_median', 'hc_stdev', 'hc_samples',
#        'hc_sample_weight', 'home_equity_second_mortgage', 'second_mortgage',
#        'home_equity', 'debt', 'second_mortgage_cdf', 'home_equity_cdf',
# ...

# %%
sns.distplot(df_train_2500.family_mean)
plt.title("Family income distribution chart")
plt.show()
# Out:
# C:\Users\91965\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df_train_2500.hi_mean)
plt.title(" house hold income distribution chart")
plt.show()
# Out:
# C:\Users\91965\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df_train_2500.family_mean - df_train_2500.hi_mean )
plt.title("Remaining income distrubution chart")
plt.show()
# Out:
# C:\Users\91965\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Exploratory Data Analysis (EDA):
#
# 1. Perform EDA and come out with insights into population density and age. You may have to derive new fields (make sure to weight averages for accurate measurements):

# %% [markdown]
# ## a) Use pop and ALand variables to create a new field called population density

# %%
df_train[['pop','ALand']]
# Out:
#         pop         ALand
# 0      3727  5.092349e+08
# 1      1941  2.371512e+06
# 2      5981  1.979230e+06
# 3      5476  2.089774e+06
# 4      5893  2.936374e+06
# ...     ...           ...
# 27316  2509  3.492763e+07
# 27317  7986  7.781997e+07
# 27318  6629  2.953930e+09
# 27319  2578  1.993203e+06
# 27320  3710  1.108001e+08
#
# [27321 rows x 2 columns]

# %%
df_train['pop_density'] =  df_train['pop'] / df_train['ALand'] 
df_train.pop_density
# Out:
# 0        0.000007
# 1        0.000818
# 2        0.003022
# 3        0.002620
# 4        0.002007
#            ...
# 27316    0.000072
# 27317    0.000103
# 27318    0.000002
# 27319    0.001293
# 27320    0.000033
# Name: pop_density, Length: 27321, dtype: float64

# %% [markdown]
# ## b) Use male_age_median, female_age_median, male_pop, and female_pop to create a new field called median age

# %%
df_train['median_age'] = (df_train['male_age_median']  + df_train['female_age_median'])/2
df_train.median_age
# Out:
# 0        39.500000
# 1        34.000000
# 2        30.958335
# 3        27.208330
# 4        31.750000
#            ...
# 27316    38.125000
# 27317    36.708335
# 27318    36.916665
# 27319    36.958335
# 27320    39.708330
# Name: median_age, Length: 27321, dtype: float64

# %% [markdown]
# ## c) Visualize the findings using appropriate chart type

# %%
sns.displot(df_train.median_age)
plt.title("median age distribution chart")
plt.show()

# %%
sns.boxplot(df_train['median_age'])
plt.title('Population Density')
plt.show()
# Out:
# C:\Users\91965\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## 2. Create bins for population into a new variable by selecting appropriate class interval so that the number of categories don’t exceed 5 for the ease of analysis.

# %%
df_train['pop'].describe()
# Out:
# count    27321.000000
# mean      4316.032685
# std       2169.226173
# min          0.000000
# 25%       2885.000000
# 50%       4042.000000
# 75%       5430.000000
# max      53812.000000
# Name: pop, dtype: float64

# %%
df_train['pop_bins']=pd.cut(df_train['pop'],[0,2885,4042,5430,10000,53812],labels=['verylow','low','avg','high','veryhigh'])

# %%
df_train[['pop','pop_bins']]
# Out:
#         pop pop_bins
# 0      3727      low
# 1      1941  verylow
# 2      5981     high
# 3      5476     high
# 4      5893     high
# ...     ...      ...
# 27316  2509  verylow
# 27317  7986     high
# 27318  6629     high
# 27319  2578  verylow
# 27320  3710      low
#
# [27321 rows x 2 columns]

# %%
df_train.pop_bins.value_counts()
# Out:
# avg         6830
# low         6827
# verylow     6654
# high        6458
# veryhigh     370
# Name: pop_bins, dtype: int64

# %%
df_train.groupby(by="pop_bins")[['married','separated','divorced']].count()
# Out:
#           married  separated  divorced
# pop_bins
# verylow      6654       6654      6654
# low          6827       6827      6827
# avg          6830       6830      6830
# high         6458       6458      6458
# veryhigh      370        370       370

# %%
df_train.groupby(by="pop_bins")[['married','separated','divorced']].agg(["mean","median"])
# Out:
#            married           separated           divorced
#               mean    median      mean   median      mean    median
# pop_bins
# verylow   0.472568  0.492430  0.022061  0.01440  0.111123  0.105340
# low       0.507273  0.523310  0.018803  0.01338  0.103143  0.099130
# avg       0.515832  0.527880  0.018417  0.01359  0.097121  0.093690
# high      0.534311  0.549920  0.017233  0.01271  0.090623  0.086250
# veryhigh  0.576828  0.591425  0.015699  0.01080  0.076945  0.070565

# %%
plt.figure(figsize=(10,5))
pop_bin_married=df_train.groupby(by='pop_bins')[['married','separated','divorced']].agg(["mean"])
pop_bin_married.plot(figsize=(20,8))
plt.show()

# %% [markdown]
# ## 3. Please detail your observations for rent as a percentage of income at an overall level, and for different states.

# %%
(df_train.rent_mean.sum() / df_train.family_mean.sum())*100
# Out:
# 1.3358170721473939

# %%
rent_state_mean = df_train.groupby(by='state')['rent_mean'].mean()
rent_state_mean.head()
# Out:
# state
# Alabama        774.004927
# Alaska        1185.763570
# Arizona       1097.753511
# Arkansas       720.918575
# California    1471.133857
# Name: rent_mean, dtype: float64

# %%
income_state_mean = df_train.groupby(by='state')['hi_mean'].mean()
income_state_mean.head()
# Out:
# state
# Alabama       57593.092145
# Alaska        83691.648111
# Arizona       66959.157590
# Arkansas      55315.150893
# California    82108.843457
# Name: hi_mean, dtype: float64

# %%
rent_percent = rent_state_mean/income_state_mean
rent_percent.head()
# Out:
# state
# Alabama       0.013439
# Alaska        0.014168
# Arizona       0.016394
# Arkansas      0.013033
# California    0.017917
# dtype: float64

# %% [markdown]
# ## 4. Perform correlation analysis for all the relevant variables by creating a heatmap. Describe your findings.

# %%
df_train_num = df_train.select_dtypes(exclude=object)
df_train_num.drop(['pop_bins'], axis=1, inplace = True)

# %%
cor=df_train[['COUNTYID','STATEID','zip_code','type','pop', 'family_mean',
         'second_mortgage', 'home_equity', 'debt','hs_degree','pct_own', 'married','separated', 'divorced']].corr()

# %%
plt.figure(figsize=(20,10))
sns.heatmap(cor,annot=True,cmap='PuBuGn')
plt.show()

# %%
heatmap = plt.figure(figsize=(20,5))
sns.heatmap(cor,annot=True,cmap='PuBuGn')
plt.show()

# %% [markdown]
# ## Project Task: Week 3

# %% [markdown]
#  1. The economic multivariate data has a significant number of measured variables. The goal is to find where the measured variables depend on a number of smaller unobserved common factors or latent variables. 2. Each variable is assumed to be dependent upon a linear combination of the common factors, and the coefficients are known as loadings. Each measured variable also includes a component due to independent random variability, known as “specific variance” because it is specific to one variable. Obtain the common factors and then plot the loadings. Use factor analysis to find latent variables in our dataset and gain insight into the linear relationships in the data. Following are the list of latent variables:

# %%
# !pip install factor_analyzer

# %%
from sklearn.decomposition import FactorAnalysis
from factor_analyzer import FactorAnalyzer

# %%
fa = FactorAnalysis(n_components=5)
fa.fit_transform(df_train_num)
# Out:
# array([[ 2.95896512e-01, -1.61936933e-01, -1.73975363e+00,
#          1.30523181e+00,  2.14231611e+00],
#        [-9.89651902e-02,  6.36812237e-02, -1.76611542e+00,
#          1.28455452e+00, -2.01323508e-01],
#        [-9.98358092e-02,  1.37706930e-02, -1.76646417e+00,
#          1.28772138e+00,  8.78969393e-02],
#        ...,
#        [ 2.20278586e+00, -1.03746928e+00, -8.31264000e-01,
#         -2.07655145e+00,  4.99925915e-01],
#        [-9.98249112e-02,  1.37655957e-02, -9.79223147e-01,
#         -2.09745524e+00, -4.57526747e-01],
#        [-1.49520973e-02, -2.50038658e-02, -9.82712405e-01,
#         -2.09681865e+00, -1.21578055e-03]])

# %%
df_train.drop(['pop_bins'],axis=1, inplace = True)
df_train.to_excel("Project_train.xlsx")

# %% [markdown]
# ## Project Task: Week 4
# ### Data Modeling :
#
# 1. Build a linear Regression model to predict the total monthly expenditure for home mortgages loan. Please refer ‘deplotment_RE.xlsx’. Column hc_mortgage_mean is predicted variable. This is the mean monthly     mortgage and owner costs of specified geographical location. Note: Exclude loans from prediction model which have NaN (Not a Number) values for hc_mortgage_mean.
#
# a) Run a model at a Nation level. If the accuracy levels and R square are not satisfactory proceed to below step.
#
# b) Run another model at State level. There are 52 states in USA.
#
# c) Keep below considerations while building a linear regression model. Data Modeling :
#
# • Variables should have significant impact on predicting Monthly mortgage and owner costs
#
# • Utilize all predictor variable to start with initial hypothesis
#
# • R square of 60 percent and above should be achieved
#
# • Ensure Multi-collinearity does not exist in dependent variables
#
# • Test if predicted variable is normally distributed

# %%
df_train.columns
# Out:
# Index(['UID', 'SUMLEVEL', 'COUNTYID', 'STATEID', 'state', 'state_ab', 'city',
#        'place', 'type', 'primary', 'zip_code', 'area_code', 'lat', 'lng',
#        'ALand', 'AWater', 'pop', 'male_pop', 'female_pop', 'rent_mean',
#        'rent_median', 'rent_stdev', 'rent_sample_weight', 'rent_samples',
#        'rent_gt_10', 'rent_gt_15', 'rent_gt_20', 'rent_gt_25', 'rent_gt_30',
#        'rent_gt_35', 'rent_gt_40', 'rent_gt_50', 'universe_samples',
#        'used_samples', 'hi_mean', 'hi_median', 'hi_stdev', 'hi_sample_weight',
#        'hi_samples', 'family_mean', 'family_median', 'family_stdev',
#        'family_sample_weight', 'family_samples', 'hc_mortgage_mean',
#        'hc_mortgage_median', 'hc_mortgage_stdev', 'hc_mortgage_sample_weight',
#        'hc_mortgage_samples', 'hc_mean', 'hc_median', 'hc_stdev', 'hc_samples',
#        'hc_sample_weight', 'home_equity_second_mortgage', 'second_mortgage',
#        'home_equity', 'debt', 'second_mortgage_cdf', 'home_equity_cdf',
# ...

# %%
df_train.type.unique()
# Out:
# array(['City', 'Town', 'CDP', 'Village', 'Borough', 'Urban'], dtype=object)

# %%
type_dict = {'type' :{"City" : 1, 'Urban' : 2, 'Town' : 3, 'CDP' : 4, 'Village' : 5,'Borough' : 6 }}
type_dict
# Out:
# {'type': {'City': 1,
#   'Urban': 2,
#   'Town': 3,
#   'CDP': 4,
#   'Village': 5,
#   'Borough': 6}}

# %%
df_train.replace(type_dict, inplace = True)

# %%
df_train.type.unique()
# Out:
# array([1, 3, 4, 5, 6, 2], dtype=int64)

# %%
df_test.replace(type_dict, inplace = True)
df_test.type.unique()
# Out:
# array([1, 3, 4, 5, 6, 2], dtype=int64)

# %%
feature_cols=['COUNTYID','STATEID','zip_code','type','pop', 'family_mean','second_mortgage', 'home_equity', 'debt','hs_degree',
              'pct_own', 'married','separated', 'divorced']

# %%
x_train = df_train[feature_cols]
y_train = df_train.hc_mortgage_mean

# %%
x_test = df_test[feature_cols]
y_test = df_test.hc_mortgage_mean

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (27321, 14)
# (27321,)
# (11709, 14)
# (11709,)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, accuracy_score

# %%
SC = StandardScaler()
x_train_sc = SC.fit_transform(x_train)
x_test_sc = SC.fit_transform(x_test)

# %% [markdown]
# ## Run a model at a Nation level. If the accuracy levels and R square are not satisfactory proceed to below step.

# %%
linreg = LinearRegression()
linreg.fit(x_train_sc,y_train)
# Out:
# LinearRegression()

# %%
y_pred = linreg.predict(x_test_sc)

# %%
print ("R2 score of Linear Regression Model : ", r2_score(y_test,y_pred) )
print ("mean absolute error : ", mean_absolute_error(y_test,y_pred))
print ("Root mean squared error: ", np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# R2 score of Linear Regression Model :  0.7264712920157363
# mean absolute error :  235.80971432701529
# Root mean squared error:  328.1492774668087

# %% [markdown]
# ## Run another model at State level. There are 52 states in USA.

# %%
State = df_train['STATEID'].unique()
State
# Out:
# array([ 2,  1,  5,  4,  6,  8,  9, 11, 10, 12, 13, 15, 19, 16, 17, 18, 20,
#        21, 22, 25, 24, 23, 26, 27, 29, 28, 30, 37, 38, 31, 33, 34, 35, 32,
#        36, 39, 40, 41, 42, 72, 44, 45, 46, 47, 48, 49, 51, 50, 53, 55, 54,
#        56], dtype=int64)

# %%
for i in [27,3,11,15]:
    print("State ID-",i)
    
    x_train_nation=df_train[df_train['COUNTYID']==i][feature_cols]
    y_train_nation=df_train[df_train['COUNTYID']==i]['hc_mortgage_mean']
    
    x_test_nation=df_test[df_test['COUNTYID']==i][feature_cols]
    y_test_nation=df_test[df_test['COUNTYID']==i]['hc_mortgage_mean']
    
    x_train_scaled_nation=SC.fit_transform(x_train_nation)
    x_test_scaled_nation=SC.fit_transform(x_test_nation)
    
    linreg.fit(x_train_scaled_nation,y_train_nation)
    y_pred_nation=linreg.predict(x_test_scaled_nation)
    
    print("Overall R2 score of linear regression model for state,",i,":" ,r2_score(y_test_nation,y_pred_nation))
    print("Overall RMSE of linear regression model for state,",i,":" ,np.sqrt(mean_squared_error(y_test_nation,y_pred_nation)))
    print('\n')
# Out:
# State ID- 27
# Overall R2 score of linear regression model for state, 27 : 0.8578495796467325
# Overall RMSE of linear regression model for state, 27 : 225.64566828893905
#
#
# State ID- 3
# Overall R2 score of linear regression model for state, 3 : 0.6664973252183204
# Overall RMSE of linear regression model for state, 3 : 359.3274341205885
#
#
# State ID- 11
# Overall R2 score of linear regression model for state, 11 : 0.7400053636770512
# Overall RMSE of linear regression model for state, 11 : 241.12966547383874
#
#
# State ID- 15
# Overall R2 score of linear regression model for state, 15 : 0.7921382591256213
# Overall RMSE of linear regression model for state, 15 : 211.37572315409523

# %%
plt.figure(figsize=(10,10))

plt.subplot(2,2,1)
sns.distplot(y_pred)
plt.title("y_pred")

plt.subplot(2,2,2)
sns.distplot(y_pred_nation)
plt.title("y_pred_nation")

plt.show()
# Out:
# C:\Users\91965\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\91965\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df_train.isna().sum()[df_train.isna().sum()>1]
# Out:
# Series([], dtype: int64)

# %%
df_train['bad_debts'] =  df_train['second_mortgage'] + df_train ['home_equity'] - df_train['home_equity_second_mortgage']
df_train['good_debt'] = df_train.debt - df_train.bad_debts
df_train.good_debt
# Out:
# 0        0.65813
# 1        0.73743
# 2        0.58732
# 3        0.69521
# 4        0.62165
#           ...
# 27316    0.46617
# 27317    0.60928
# 27318    0.42687
# 27319    0.47200
# 27320    0.41484
# Name: good_debt, Length: 27321, dtype: float64

# %% [markdown]
# ##  Data Reporting:
#
# 2. Create a dashboard in tableau by choosing appropriate chart types and metrics useful for the business. The dashboard must entail the following:
#
# a) Box plot of distribution of average rent by type of place (village, urban, town, etc.).
#
# b) Pie charts to show overall debt and bad debt.
#
# c) Explore the top 2,500 locations where the percentage of households with a second mortgage is the highest and percent ownership is above 10 percent. Visualize using geo-map.
#
# d) Heat map for correlation matrix.
#
# e) Pie chart to show the population distribution across different types of places (village, urban, town etc.)
